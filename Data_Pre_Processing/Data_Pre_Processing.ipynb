# %% [markdown]
# <a href="https://colab.research.google.com/github/iffathsaleem/DSPL_ICW/blob/main/Data_Pre_Processing/Data_Pre_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/iffathsaleem/DSPL_ICW/refs/heads/main/Data_Pre_Processing/health_lka.csv'
health = pd.read_csv(url)

# %%
health = health[['Year','Indicator Name', 'Value']]

# %%
health = health.drop(0)

# %%
health.head()
# Out:
#    Year                                     Indicator Name Value
# 1  2020  Total alcohol consumption per capita, female (...  1.05
# 2  2019  Total alcohol consumption per capita, female (...  1.02
# 3  2018  Total alcohol consumption per capita, female (...  1.02
# 4  2017  Total alcohol consumption per capita, female (...  1.03
# 5  2016  Total alcohol consumption per capita, female (...  1.05

# %%
health = health.dropna(subset=['Year', 'Value'])

# %%
health = health[health['Year'].apply(lambda x: str(x).isdigit())]
health['Year'] = health['Year'].astype(int)

# %%
health['Indicator Name'] = health['Indicator Name'].astype(str).str.strip()

# %%
health
# Out:
#       Year                                     Indicator Name   Value
# 1     2020  Total alcohol consumption per capita, female (...    1.05
# 2     2019  Total alcohol consumption per capita, female (...    1.02
# 3     2018  Total alcohol consumption per capita, female (...    1.02
# 4     2017  Total alcohol consumption per capita, female (...    1.03
# 5     2016  Total alcohol consumption per capita, female (...    1.05
# ...    ...                                                ...     ...
# 8147  2002  Number of people spending more than 10% of hou...  504000
# 8148  1995  Number of people spending more than 10% of hou...  887000
# 8149  2009  Number of people spending more than 25% of hou...   20000
# 8150  2002  Number of people spending more than 25% of hou...    9000
# 8151  1995  Number of people spending more than 25% of hou...   93000
#
# [8151 rows x 3 columns]

# %%
health['Value'] = pd.to_numeric(health['Value'], errors='coerce')

# %%
unique_indicators = health['Indicator Name'].unique()

# %%
indicator_map = {name: f"IND_{str(i+1).zfill(3)}" for i, name in enumerate(unique_indicators)}

# %%
health['Indicator_Code'] = health['Indicator Name'].map(indicator_map)

# %%
health
# Out:
#       Year                                     Indicator Name      Value  \
# 1     2020  Total alcohol consumption per capita, female (...       1.05
# 2     2019  Total alcohol consumption per capita, female (...       1.02
# 3     2018  Total alcohol consumption per capita, female (...       1.02
# 4     2017  Total alcohol consumption per capita, female (...       1.03
# 5     2016  Total alcohol consumption per capita, female (...       1.05
# ...    ...                                                ...        ...
# 8147  2002  Number of people spending more than 10% of hou...  504000.00
# 8148  1995  Number of people spending more than 10% of hou...  887000.00
# 8149  2009  Number of people spending more than 25% of hou...   20000.00
# 8150  2002  Number of people spending more than 25% of hou...    9000.00
# 8151  1995  Number of people spending more than 25% of hou...   93000.00
#
#      Indicator_Code
# 1           IND_001
# 2           IND_001
# 3           IND_001
# ...

# %%
health['Value_original'] = health['Value']

# %%
health['Value_converted'] = health['Value_original'].astype(float)

# %%
changed_rows = health[health['Value_original'] != health['Value_converted']]

# %%
health.to_csv("Sri Lanka Health Statistics.csv", index=False)
