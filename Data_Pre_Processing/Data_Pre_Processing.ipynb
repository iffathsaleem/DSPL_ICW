# %% [markdown]
# <a href="https://colab.research.google.com/github/iffathsaleem/DSPL_ICW/blob/main/Data_Pre_Processing/Data_Pre_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/iffathsaleem/DSPL_ICW/refs/heads/main/Data_Pre_Processing/health_lka.csv'
health = pd.read_csv(url)

# %%
health = health[['Year', 'Indicator Name', 'Value']]

# %%
health = health.drop(0).reset_index(drop=True)

# %%
health = health.dropna(subset=['Year', 'Value'])

# %%
health = health[health['Year'].apply(lambda x: str(x).isdigit())]

# %%
health['Indicator Name'] = health['Indicator Name'].astype(str).str.strip()

# %%
health['Value'] = pd.to_numeric(health['Value'], errors='coerce')

# %%
unique_indicators = health['Indicator Name'].unique()
indicator_map = {name: f"IND_{str(i+1).zfill(3)}" for i, name in enumerate(unique_indicators)}
health['Indicator_Code'] = health['Indicator Name'].map(indicator_map)

# %%
def is_percentage(indicator_name):
    return "%" in indicator_name or "percent" in indicator_name.lower()

# %%
health['is_percentage'] = health['Indicator Name'].apply(is_percentage)

# %%
health
# Out:
#       Year                                     Indicator Name      Value  \
# 0     2020  Total alcohol consumption per capita, female (...       1.05
# 1     2019  Total alcohol consumption per capita, female (...       1.02
# 2     2018  Total alcohol consumption per capita, female (...       1.02
# 3     2017  Total alcohol consumption per capita, female (...       1.03
# 4     2016  Total alcohol consumption per capita, female (...       1.05
# ...    ...                                                ...        ...
# 8146  2002  Number of people spending more than 10% of hou...  504000.00
# 8147  1995  Number of people spending more than 10% of hou...  887000.00
# 8148  2009  Number of people spending more than 25% of hou...   20000.00
# 8149  2002  Number of people spending more than 25% of hou...    9000.00
# 8150  1995  Number of people spending more than 25% of hou...   93000.00
#
#      Indicator_Code  is_percentage
# 0           IND_001          False
# 1           IND_001          False
# 2           IND_001          False
# 3           IND_001          False
# 4           IND_001          False
# ...             ...            ...
# 8146        IND_251           True
# 8147        IND_251           True
# 8148        IND_252           True
# 8149        IND_252           True
# 8150        IND_252           True
#
# [8151 rows x 5 columns]

# %%
health.to_csv("Sri_Lanka_Health_Statistics.csv", index=False)
